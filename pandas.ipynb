# %%
import pandas as pd

# %%
df = pd.read_csv("/workspace/datasets/train.csv")

# %%
df.head()
# Out:
#                                        user      sku            category  \
# 0  000000df17cd56a5df4a94074e133c9d4739fae3  2125233        abcat0101001
# 1  000001928162247ffaf63185cd8b2a244c78e7c6  2009324        abcat0101001
# 2  000017f79c2b5da56721f22f9fdd726b13daf8e8  1517163  pcmcat193100050014
# 3  000017f79c2b5da56721f22f9fdd726b13daf8e8  2877125        abcat0101001
# 4  000017f79c2b5da56721f22f9fdd726b13daf8e8  2877134        abcat0101005
#
#                                  query               click_time  \
# 0  Televisiones Panasonic  50 pulgadas  2011-09-01 23:44:52.533
# 1                                Sharp   2011-09-05 12:25:37.42
# 2                                 nook   2011-08-24 12:56:58.91
# 3                                  rca  2011-10-25 07:18:14.722
# 4                                  rca  2011-10-25 07:19:51.697
#
#                 query_time
# 0  2011-09-01 23:43:59.752
# 1  2011-09-05 12:25:01.187
# 2  2011-08-24 12:55:13.012
# ...

# %%
gb = df.groupby("query")
gb.first()
# Out:
#                                                                                         user  \
# query
# !pod                                                ee0c57592de376bf9e687eaab46c05f6d8e15988
# #                                                   0240c3e637c81f402565ce97978c032b2f6454f3
# # 1 hits of the 50s                                 22ee0cd6a6dce1df2f5487ed6a6faa6b78c8fb06
# # TC-P50GT30                                        144d310cedd839dc33d5dddc8847b90a1347b048
# #1 Girl                                             e9fbedbfa8d6d3309b00871185a73aa40019321c
# ...                                                                                      ...
# ��Mfr: SONY ��Model: VPCYB/15KX/P �� ��UPC: 027...  1b4cd9dccc522a5aa0ef1e146c5277ce704c821e
# ��Mfr: TOSHIBA ��Model: BDX4200 ��                  28e001b8f0605e7b3a2eac7ec21c80ea10af3488
# ��Model: U30JCB2B                                   d512aff4d504f12273f069830226aac45ed8b432
# ...

# %%
gb.get_group("ipad").count()
# Out:
# user          5036
# sku           5036
# category      5036
# query         5036
# click_time    5036
# query_time    5036
# dtype: int64

# %%
df[df["category"] == "abcat0101001"]
# Out:
#                                              user      sku      category  \
# 0        000000df17cd56a5df4a94074e133c9d4739fae3  2125233  abcat0101001
# 1        000001928162247ffaf63185cd8b2a244c78e7c6  2009324  abcat0101001
# 3        000017f79c2b5da56721f22f9fdd726b13daf8e8  2877125  abcat0101001
# 19       0000c4e9d7075985d1020c456e7ce36f83f834eb  2126065  abcat0101001
# 40       00017f7beeac02736c0ce7bf1e75f3010939b34e  1831054  abcat0101001
# ...                                           ...      ...           ...
# 1865071  fff7afecf87f8043ce4b4fcbd8ed47d7ffd52679  2620821  abcat0101001
# 1865077  fff7edfacf2c376fa8ea4f637c33013d057ae70a  1854328  abcat0101001
# 1865119  fff97c95234212c39d6f04c9854fa94d94bc0cce  1854819  abcat0101001
# 1865190  fffc750c85c62fe732b8223d5872be6e0fc03593  2262074  abcat0101001
# 1865224  fffd4ebf04febc87ca4b34c730c78d7bf1bef564  2620821  abcat0101001
#
#                                            query               click_time  \
# ...

# %%
df.sample(n=100)
# Out:
#                                              user      sku  \
# 1171919  a0dd4a85f277fcd0e6d19e979698c3370223989a  8216487
# 1371868  bc592ede77209ebb76bbddcb6b5ec26f3e86d9dc  1947053
# 1845318  fd42594ec38dfa9dd59a322c9d2f01351ba2a563  2817255
# 240363   21203dffd534459ce603640662925ca499b9b2cd  2265381
# 831421   725e9d3de05d49549f33e6b26393f6b7a90a7ba3  9926019
# ...                                           ...      ...
# 135207   12a89c80d3b1399d6c0b1af497746b16e2fdd8c3  5431927
# 916164   7df7a3c1921f6fa553f8a42499955fc63ef1a437  2525772
# 224653   1f072b7c3b3236a90e7b9e22a577092e69234b06  1945531
# 482945   42641add9346c864d4ea2124f1092275c590e28d  8415958
# 1266218  ade4d3a3638d694d7d808e0f0d0e42ff1e65fc82  7323087
#
#                    category                    query               click_time  \
# 1171919        abcat0506002                   pc2100  2011-10-20 00:03:46.052
# 1371868        abcat0908002             dehumidifier  2011-10-06 23:16:53.666
# ...
